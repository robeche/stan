# %%
import torch
 
# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA GeForce RTX 5080

# %%
# Verificar detalles de PyTorch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version (compiled with): {torch.version.cuda}")
print(f"Number of GPUs: {torch.cuda.device_count()}")
# Out:
# PyTorch version: 2.9.1+cu128
# CUDA available: True
# CUDA version (compiled with): 12.8
# Number of GPUs: 1

# %% [markdown]
# ---
# ### ⚠️ IMPORTANTE: Reinicia el kernel del notebook
# Presiona el botón "Restart" en la barra de herramientas del notebook o usa `Ctrl+Shift+P` → "Restart Kernel"
#
# Luego ejecuta la celda 1 nuevamente para verificar que ahora detecta la GPU.
